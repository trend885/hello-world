# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# define p(x), q(x) and other parameters
M = 1.2
sigma = 0.45

def p(x):
    y = np.where(x<0, x+1, 1-x)
    y[np.abs(x)>1] = 0
    return(y)

def make_q(mu, sigma):
    return lambda x: 1/(sigma * np.sqrt(2*np.pi)) * np.exp( - 0.5 * (x - mu)**2 / sigma**2)

q = make_q(0, sigma)

x = np.linspace(-1,1,100)

plt.plot(x, p(x))
plt.plot(x, M*q(x))
plt.show()

N = int(1e5)
x = np.random.normal(0, sigma, N)
alpha = p(x) / (M*q(x))
accepted = np.random.rand(N) < alpha

sns.distplot(x[accepted]);
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-d8140e68f967> in <module>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5
#       6 # define p(x), q(x) and other parameters
#
# ImportError: No module named seaborn

# %%
# HAZİNE
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# define p(x), q(x) and other parameters
M = 1.2
sigma = 0.45

def p(x):
    y = np.where(x<0, x+1, 1-x)
    y[np.abs(x)>1] = 0
    return(y)

def make_q(mu, sigma):
    return lambda x: 1/(sigma * np.sqrt(2*np.pi)) * np.exp( - 0.5 * (x - mu)**2 / sigma**2)

q = make_q(0, sigma)

x = np.linspace(-1,1,100)

plt.plot(x, p(x))
plt.plot(x, M*q(x))
plt.show()

N = int(1e5)
x = np.random.normal(0, sigma, N)
alpha = p(x) / (M*q(x))
accepted = np.random.rand(N) < alpha

sns.distplot(x[accepted]);
